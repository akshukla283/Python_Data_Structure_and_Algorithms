# %% [markdown]
# ### Doubly Linked List in Python
#
# A doubly linked list is a python data structure wherein the data elements are stored as nodes. In a doubly linked list, each node of the list has two references, one of the previous node and the other of the next node.
#
#
# Thus, each node holds two addresses along with the data value. Since each node has two references, a doubly linked list allows us to traverse in both directions.
#
# #### Creation of a Doubly Linked List
# To create a doubly linked list, we initialize the node and linked list class. Next, we set up our list by creating its first element and assigning the “head” and “tail” references to it.
#
#
# #### Algorithm to create a Doubly Linked List
# * Step 1:
#  Create a node class with the three required data variables.
# * Step 2:
#  Create the Doubly Linked List class and declare the head and tail nodes.
# * Step 3:
#  Create a new node and assign it a value.
# * step 4:
#  Set the “next” reference of the newly created node to none.
# * Step 5:
#  Set the “prev” reference of the newly created node to none.
# * Step 6:
#  Set both the head and tail references to the new node.
# * Step 7:
#  Terminate.
# #### Method to create a Doubly Linked List

# %%
## Creating Node class

class Node:
    def __init__(self, data = None):
        self.data = data
        self.next = None
        self.prev = None
        
# Create a doubly Linked list class to initialize head and tail reference

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
          
    # Function to create Doubly Linked List
    def createDLL(self, data):
        new_node = Node(data)
        new_node.next =None
        new_node.prev = None
        self.head = new_node
        self.tail = new_node
        print("The doubly linked list has be created!")

# %% [markdown]
# #### The iterator function
# `Since the custom-created linked list is not iterable, we have to add an “__iter__” function so as to traverse through the list.`

# %%
## Creating Node class

class Node:
    def __init__(self, data = None):
        self.data = data
        self.next = None
        self.prev = None
        
# Create a doubly Linked list class to initialize head and tail reference

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
    #Iteration Function
    
    def __iter__(self):
        node = self.head
        while node:
            yield node
            node = node.next
          
    # Function to create Doubly Linked List
    def createDLL(self, data):
        new_node = Node(data)
        new_node.next =None
        new_node.prev = None
        self.head = new_node
        self.tail = new_node
        print("The doubly linked list has be created!")
        

# Initialize the linked list with a new node

dll1 = DoublyLinkedList()
dll1.createDLL(4)
print([node.data for node in dll1])

try:
    print("Head : ", dll1.head.data)
    print("Tail : ", dll1.tail.data)
    
except Exception as e:
    print(e)
# Out:
# The doubly linked list has be created!
# [4]
# Head :  4
# Tail :  4

# %% [markdown]
# #### Time and Space Complexity
# `The time complexity for initializing a doubly linked list is O(1). The space complexity is O(1) as no additional memory is required to initialize the linked list.`
#
# #### Insertion in Doubly Linked List
# A node can be inserted in a doubly linked list in any one of the following  ways.
#
# * Insert empty
# * At the beginning of the linked list
# * Add new node after particular node
# * Add new node before particular node
# * At the end of the linked list
#
#
# ###  Insertion Algorithm
#
# ### 1. Insert Empty
#
# * Adding node when Linked List is empty!

# %%
## Creating Node class

class Node:
    def __init__(self, data = None):
        self.data = data
        self.next = None
        self.prev = None
        
# Create a doubly Linked list class to initialize head and tail reference

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
    #Iteration Function
    
    def __iter__(self):
        node = self.head
        while node:
            yield node
            node = node.next
          
    # Function to create Doubly Linked List
    def createDLL(self, data):
        new_node = Node(data)
        new_node.next =None
        new_node.prev = None
        self.head = new_node
        self.tail = new_node
        print("The doubly linked list has be created!")
        
    ## ------------------- Insertion Operaton -------------------------------------
    
    # 1. Insert_empty()
    # Function to insert node when Linked List is empty.
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
            self.tail = new_node
            print("The doubly linked list has be created!")
            
        else:
            print("Node is not empty!")
        

# Initialize the linked list with a new node

dll1 = DoublyLinkedList()
# dll1.createDLL(4)
dll1.insert_empty(10)
# dll1.insert_empty(100)
print([node.data for node in dll1])

try:
    print("Head : ", dll1.head.data)
    print("Tail : ", dll1.tail.data)
    
except Exception as e:
    print(e)
# Out:
# The doubly linked list has be created!
# Node is not empty!
# [10]
# Head :  10
# Tail :  10

# %% [markdown]
# ### 2. Algorithm to insert a node at the beginning
#
# * Step 1:
# Create a node and assign a value to it.
# * Step 2:
# Assign the “prev” reference of head as the new node.
# * Step 3:
# Assign the “next” reference of the node as head.
# * Step 4:
# Set the created node as the new head.
# * Step 5:
# Terminate.
#
# ####  Method to insert a node at the beginning

# %%
## Creating Node class

class Node:
    def __init__(self, data = None):
        self.data = data
        self.next = None
        self.prev = None
        
# Create a doubly Linked list class to initialize head and tail reference

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
    #Iteration Function
    
    def __iter__(self):
        node = self.head
        while node:
            yield node
            node = node.next
          
    # Function to create Doubly Linked List
    def createDLL(self, data):
        new_node = Node(data)
        new_node.next =None
        new_node.prev = None
        self.head = new_node
        self.tail = new_node
        print("The doubly linked list has be created!")
        
    ## ------------------- Insertion Operaton -------------------------------------
    
    # 1. Insert_empty()
    # Function to insert node when Linked List is empty.
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
            self.tail = new_node
            print("The doubly linked list has be created!")
            
        else:
            print("Node is not empty!")
            
    # 2. Add_begin()
    # Function to add node in the beginning
    def add_begin(self, data):
        if self.head is None:
            return self.insert_empty(data)
        else:
            new_node = Node(data)
            
            self.head.prev = new_node
            new_node.next = self.head
            self.head = new_node
            
        
        

# Initialize the linked list with a new node

dll1 = DoublyLinkedList()
# dll1.createDLL(4)
# dll1.insert_empty(10)

# dll1.insert_empty(100)
dll1.add_begin(20)
dll1.add_begin(50)
dll1.add_begin(90)
dll1.add_begin(200)


print([node.data for node in dll1])

try:
    print("Head : ", dll1.head.data)
    print("Tail : ", dll1.tail.data)
    
except Exception as e:
    print(e)
# Out:
# The doubly linked list has be created!
# [200, 90, 50, 20]
# Head :  200
# Tail :  20

# %% [markdown]
# ### 3. Algorithm to Add a node in after the particular node of linked list
# * Step 1: Create a node and assign a value to it.
# * Step 2: If the previous node doesn’t exist, return an error message and move to step 5.
# * Step 3: Set the “next” reference of the previous node to the new node and set the “prev” reference of the new node to the previous node.
# * Step 4: Set the “next” reference of the new node to the next node and set the “prev” reference of the next node to the new node.
# * Step 5: Terminate.
#
# #### Method to Add a node after particular node of the linked list

# %%
## Creating Node class

class Node:
    def __init__(self, data = None):
        self.data = data
        self.next = None
        self.prev = None
        
# Create a doubly Linked list class to initialize head and tail reference

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
    #Iteration Function
    
    def __iter__(self):
        node = self.head
        while node:
            yield node
            node = node.next
          
    # Function to create Doubly Linked List
    def createDLL(self, data):
        new_node = Node(data)
        new_node.next =None
        new_node.prev = None
        self.head = new_node
        self.tail = new_node
        print("The doubly linked list has be created!")
        
    ## ------------------- Insertion Operaton -------------------------------------
    
    # 1. Insert_empty()
    # Function to insert node when Linked List is empty.
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
            self.tail = new_node
            print("The doubly linked list has be created!")
            
        else:
            print("Node is not empty!")
            
    # 2. Add_begin()
    # Function to add node in the beginning
    def add_begin(self, data):
        if self.head is None:
            return self.insert_empty(data)
        else:
            new_node = Node(data)
            
            self.head.prev = new_node
            new_node.next = self.head
            self.head = new_node
            
    # 3. add_after()
    # Function to add node after particular node
    # in add after method we need to when node is last node because in that tail reference will
    # be change as per the new node
    def add_after(self, data, prev_node):
        
        if self.head is None:
            print("Doubly linked list is empty!")
            return
        
        node = self.head
        while node.next != None:
            if node.data == prev_node:
                break
            node = node.next
            
        if node.next != None:#means node.data == prev_node and loop terminated by first break
            new_node = Node(data)
            
            new_node.next = node.next
            new_node.prev = node
            node.next.prev = new_node
            node.next = new_node
            
        else: # this time node.next == None # we can check whether last node is the prev_node
            if node.data == prev_node:
                new_node = Node(data)
                
                node.next = new_node
                new_node.prev = node
                self.tail = new_node
                # note end node next will be None leave it as its
                
                
            else:
                print(f"Given node {prev_node} not found in Circular Linked List!")
        
        
        

# Initialize the linked list with a new node

dll1 = DoublyLinkedList()
# dll1.createDLL(4)
# dll1.insert_empty(10)

# dll1.insert_empty(100)
dll1.add_begin(20)
dll1.add_begin(50)
dll1.add_begin(90)
dll1.add_begin(200)

dll1.add_after(500, 20)
print([node.data for node in dll1])

try:
    print("Head : ", dll1.head.data)
    print("Tail : ", dll1.tail.data)
    
except Exception as e:
    print(e)
# Out:
# The doubly linked list has be created!
# [20, 500]
# Head :  20
# Tail :  500

# %% [markdown]
# ### 4. Insert node before particular node of the Linked list

# %%
## Creating Node class

class Node:
    def __init__(self, data = None):
        self.data = data
        self.next = None
        self.prev = None
        
# Create a doubly Linked list class to initialize head and tail reference

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
    #Iteration Function
    
    def __iter__(self):
        node = self.head
        while node:
            yield node
            node = node.next
          
    # Function to create Doubly Linked List
    def createDLL(self, data):
        new_node = Node(data)
        new_node.next =None
        new_node.prev = None
        self.head = new_node
        self.tail = new_node
        print("The doubly linked list has be created!")
        
    ## ------------------- Insertion Operaton -------------------------------------
    
    # 1. Insert_empty()
    # Function to insert node when Linked List is empty.
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
            self.tail = new_node
            print("The doubly linked list has be created!")
            
        else:
            print("Node is not empty!")
            
    # 2. Add_begin()
    # Function to add node in the beginning
    def add_begin(self, data):
        if self.head is None:
            return self.insert_empty(data)
        else:
            new_node = Node(data)
            
            self.head.prev = new_node
            new_node.next = self.head
            self.head = new_node
            
    # 3. add_after()
    # Function to add node after particular node
    # in add after method we need to when node is last node because in that tail reference will
    # be change as per the new node
    def add_after(self, data, prev_node):
        
        if self.head is None:
            print("Doubly linked list is empty!")
            return
        
        node = self.head
        while node.next != None:
            if node.data == prev_node:
                break
            node = node.next
            
        if node.next != None:#means node.data == prev_node and loop terminated by first break
            new_node = Node(data)
            
            new_node.next = node.next
            new_node.prev = node
            node.next.prev = new_node
            node.next = new_node
            
        else: # this time node.next == None # we can check whether last node is the prev_node
            if node.data == prev_node:
                new_node = Node(data)
                
                node.next = new_node
                new_node.prev = node
                self.tail = new_node
                # note end node next will be None leave it as its
                
                
            else:
                print(f"Given node {prev_node} not found in Circular Linked List!")
        
    # 4. add_before()
    # Function to add node before the particular node
    # important point when we add new node before first Node
    def add_before(self, data, prev_node):
        if self.head is None:
            print("Circular Doubly Linked List is empty!")
            return
        
        node = self.head
        while node.next != None:
            if node.next.data == prev_node:
                break
            node = node.next
            
        if node.next != None: 
            # means loop terminate by break statement and it can be any node except first node
            # because we started from self.head.next
            new_node = Node(data)
            
            new_node.next = node.next
            new_node.prev = node
            node.next.prev = new_node
            node.next = new_node
            
        else:  # we can check whether the first node data is data before which we want to add new
               # node. if there is only one node present then that also will be handle here
            if self.head.data == prev_node:
                new_node = Node(data)
                
                self.head.prev = new_node
                new_node.next = self.head
                self.head = new_node
                                
            else:
                print(f"Given node {prev_node} is not present in Circular Linked List!")
        

# Initialize the linked list with a new node

dll1 = DoublyLinkedList()
# dll1.createDLL(4)
# dll1.insert_empty(10)

# dll1.insert_empty(100)
dll1.add_begin(20)
# dll1.add_begin(50)
# dll1.add_begin(90)
# dll1.add_begin(200)

# dll1.add_after(500, 20)
dll1.add_before(400, 20)
print([node.data for node in dll1])

try:
    print("Head : ", dll1.head.data)
    print("Tail : ", dll1.tail.data)
    
except Exception as e:
    print(e)
# Out:
# The doubly linked list has be created!
# [400, 20]
# Head :  400
# Tail :  20

# %% [markdown]
# ###  5. Algorithm to insert a node at the end of the linked list
# * Step 1: Create a node and assign a value to it.
# * Step 2: If the list is empty, assign new node to head and tail. Move to step 6.
# * Step 3: Search for the last node. Once found, set its “next” reference pointing to the new node.
# * Step 4: Set the “prev” reference of the new node to the last node.
# * Step 5: Assign the new node as tail.
# * Step 6: Terminate.
#
# #### Method to insert a node at the end of the linked list and add a node before any other node.

# %%
## Creating Node class

class Node:
    def __init__(self, data = None):
        self.data = data
        self.next = None
        self.prev = None
        
# Create a doubly Linked list class to initialize head and tail reference

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
    #Iteration Function
    
    def __iter__(self):
        node = self.head
        while node:
            yield node
            node = node.next
          
    # Function to create Doubly Linked List
    def createDLL(self, data):
        new_node = Node(data)
        new_node.next =None
        new_node.prev = None
        self.head = new_node
        self.tail = new_node
        print("The doubly linked list has be created!")
        
    ## ------------------- Insertion Operaton -------------------------------------
    
    # 1. Insert_empty()
    # Function to insert node when Linked List is empty.
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
            self.tail = new_node
            print("The doubly linked list has be created!")
            
        else:
            print("Node is not empty!")
            
    # 2. Add_begin()
    # Function to add node in the beginning
    def add_begin(self, data):
        if self.head is None:
            return self.insert_empty(data)
        else:
            new_node = Node(data)
            
            self.head.prev = new_node
            new_node.next = self.head
            self.head = new_node
            
    # 3. add_after()
    # Function to add node after particular node
    # in add after method we need to when node is last node because in that tail reference will
    # be change as per the new node
    def add_after(self, data, prev_node):
        
        if self.head is None:
            print("Doubly linked list is empty!")
            return
        
        node = self.head
        while node.next != None:
            if node.data == prev_node:
                break
            node = node.next
            
        if node.next != None:#means node.data == prev_node and loop terminated by first break
            new_node = Node(data)
            
            new_node.next = node.next
            new_node.prev = node
            node.next.prev = new_node
            node.next = new_node
            
        else: # this time node.next == None # we can check whether last node is the prev_node
            if node.data == prev_node:
                new_node = Node(data)
                
                node.next = new_node
                new_node.prev = node
                self.tail = new_node
                # note end node next will be None leave it as its
                
                
            else:
                print(f"Given node {prev_node} not found in Circular Linked List!")
        
    # 4. add_before()
    # Function to add node before the particular node
    # important point when we add new node before first Node
    def add_before(self, data, prev_node):
        if self.head is None:
            print("Circular Doubly Linked List is empty!")
            return
        
        node = self.head
        while node.next != None:
            if node.next.data == prev_node:
                break
            node = node.next
            
        if node.next != None: 
            # means loop terminate by break statement and it can be any node except first node
            # because we started from self.head.next
            new_node = Node(data)
            
            new_node.next = node.next
            new_node.prev = node
            node.next.prev = new_node
            node.next = new_node
            
        else:  # we can check whether the first node data is data before which we want to add new
               # node. if there is only one node present then that also will be handle here
            if self.head.data == prev_node:
                new_node = Node(data)
                
                self.head.prev = new_node
                new_node.next = self.head
                self.head = new_node
                                
            else:
                print(f"Given node {prev_node} is not present in Circular Linked List!")
                
    # 5. Function to add node in the end
    def add_end(self, data):
        if self.head is None:
            return self.insert_empty(data)
        else:
            new_node = Node(data)
            
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node
        

# Initialize the linked list with a new node

dll1 = DoublyLinkedList()
# dll1.createDLL(4)
# dll1.insert_empty(10)

dll1.insert_empty(100)
# dll1.add_begin(20)
dll1.add_begin(50)
dll1.add_begin(90)
# dll1.add_begin(200)

# dll1.add_after(500, 20)
# dll1.add_before(400, 20)
dll1.add_end(300)
print([node.data for node in dll1])

try:
    print("Head : ", dll1.head.data)
    print("Tail : ", dll1.tail.data)
    
except Exception as e:
    print(e)
# Out:
# The doubly linked list has be created!
# [90, 50, 100, 300]
# Head :  90
# Tail :  300

# %% [markdown]
# ### Time and Space Complexity
# `In python, instead of iterating over the linked list and reaching the required position, we can directly jump to any point. Therefore, the time complexity of insertion in a doubly linked list is O(1).`
#
# But, for insertion at the end, the time complexity is O(N) as we need to traverse to the last element. The space complexity O(1) because it takes a constant space to add a new node.
#
# ### Traversal in Doubly Linked List
# ### Forward Traversal
# A doubly linked list can be traversed in the forward direction by iterating from the first element to the last. We get the value of the next data element by simply iterating with the help of the reference address.

# %%
## Creating Node class

class Node:
    def __init__(self, data = None):
        self.data = data
        self.next = None
        self.prev = None
        
# Create a doubly Linked list class to initialize head and tail reference

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
    #Iteration Function
    
    def __iter__(self):
        node = self.head
        while node:
            yield node
            node = node.next
            
    # Forward traversal 
    def print_Forword_LL(self):
        if self.head is None:
            print("The Linked List does not exist!")
            
        else:
            temp_node = self.head
            while temp_node:
                print(temp_node.data, "--->", end = " ")
                temp_node = temp_node.next
                
            print()
          
    # Function to create Doubly Linked List
    def createDLL(self, data):
        new_node = Node(data)
        new_node.next =None
        new_node.prev = None
        self.head = new_node
        self.tail = new_node
        print("The doubly linked list has be created!")
        
    ## ------------------- Insertion Operaton -------------------------------------
    
    # 1. Insert_empty()
    # Function to insert node when Linked List is empty.
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
            self.tail = new_node
            #print("The doubly linked list has be created!")
            
        else:
            print("Node is not empty!")
            
    # 2. Add_begin()
    # Function to add node in the beginning
    def add_begin(self, data):
        if self.head is None:
            return self.insert_empty(data)
        else:
            new_node = Node(data)
            
            self.head.prev = new_node
            new_node.next = self.head
            self.head = new_node
            
    # 3. add_after()
    # Function to add node after particular node
    # in add after method we need to when node is last node because in that tail reference will
    # be change as per the new node
    def add_after(self, data, prev_node):
        
        if self.head is None:
            print("Doubly linked list is empty!")
            return
        
        node = self.head
        while node.next != None:
            if node.data == prev_node:
                break
            node = node.next
            
        if node.next != None:#means node.data == prev_node and loop terminated by first break
            new_node = Node(data)
            
            new_node.next = node.next
            new_node.prev = node
            node.next.prev = new_node
            node.next = new_node
            
        else: # this time node.next == None # we can check whether last node is the prev_node
            if node.data == prev_node:
                new_node = Node(data)
                
                node.next = new_node
                new_node.prev = node
                self.tail = new_node
                # note end node next will be None leave it as its
                
                
            else:
                print(f"Given node {prev_node} not found in Circular Linked List!")
        
    # 4. add_before()
    # Function to add node before the particular node
    # important point when we add new node before first Node
    def add_before(self, data, prev_node):
        if self.head is None:
            print("Circular Doubly Linked List is empty!")
            return
        
        node = self.head
        while node.next != None:
            if node.next.data == prev_node:
                break
            node = node.next
            
        if node.next != None: 
            # means loop terminate by break statement and it can be any node except first node
            # because we started from self.head.next
            new_node = Node(data)
            
            new_node.next = node.next
            new_node.prev = node
            node.next.prev = new_node
            node.next = new_node
            
        else:  # we can check whether the first node data is data before which we want to add new
               # node. if there is only one node present then that also will be handle here
            if self.head.data == prev_node:
                new_node = Node(data)
                
                self.head.prev = new_node
                new_node.next = self.head
                self.head = new_node
                                
            else:
                print(f"Given node {prev_node} is not present in Circular Linked List!")
                
    # 5. Function to add node in the end
    def add_end(self, data):
        if self.head is None:
            return self.insert_empty(data)
        else:
            new_node = Node(data)
            
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node
        

# Initialize the linked list with a new node

dll1 = DoublyLinkedList()
# dll1.createDLL(4)
# dll1.insert_empty(10)

dll1.insert_empty(100)
# dll1.add_begin(20)
dll1.add_begin(50)
dll1.add_begin(90)
# dll1.add_begin(200)

# dll1.add_after(500, 20)
# dll1.add_before(400, 20)
dll1.add_end(300)
print("Linked List : ")
dll1.print_Forword_LL()
print([node.data for node in dll1])

try:
    print("Head : ", dll1.head.data)
    print("Tail : ", dll1.tail.data)
    
except Exception as e:
    print(e)
# Out:
# Linked List :
# 90 ---> 50 ---> 100 ---> 300 --->
# [90, 50, 100, 300]
# Head :  90
# Tail :  300

# %% [markdown]
# #### Reverse Traversal
# A doubly linked list can be traversed in the reverse direction by iterating from the last element to the first. We get the value of the previous data element by simply iterating with the help of the reference address.

# %%
## Creating Node class

class Node:
    def __init__(self, data = None):
        self.data = data
        self.next = None
        self.prev = None
        
# Create a doubly Linked list class to initialize head and tail reference

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
    #Iteration Function
    
    def __iter__(self):
        node = self.head
        while node:
            yield node
            node = node.next
            
    # Forward traversal 
    def print_Forword_LL(self):
        if self.head is None:
            print("The Linked List does not exist!")
            
        else:
            temp_node = self.head
            while temp_node:
                print(temp_node.data, "--->", end = " ")
                temp_node = temp_node.next
                
            print()
    
    # reverse traversal
    def print_reverse_LL(self):
        if self.head is None:
            print("The Linked List does not exist!")
        else:
            temp_head = self.tail
            while temp_head is not None:
                print(temp_head.data, "--->", end = " ")
                temp_head = temp_head.prev
            print()
          
    # Function to create Doubly Linked List
    def createDLL(self, data):
        new_node = Node(data)
        new_node.next =None
        new_node.prev = None
        self.head = new_node
        self.tail = new_node
        print("The doubly linked list has be created!")
        
    ## ------------------- Insertion Operaton -------------------------------------
    
    # 1. Insert_empty()
    # Function to insert node when Linked List is empty.
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
            self.tail = new_node
            #print("The doubly linked list has be created!")
            
        else:
            print("Node is not empty!")
            
    # 2. Add_begin()
    # Function to add node in the beginning
    def add_begin(self, data):
        if self.head is None:
            return self.insert_empty(data)
        else:
            new_node = Node(data)
            
            self.head.prev = new_node
            new_node.next = self.head
            self.head = new_node
            
    # 3. add_after()
    # Function to add node after particular node
    # in add after method we need to when node is last node because in that tail reference will
    # be change as per the new node
    def add_after(self, data, prev_node):
        
        if self.head is None:
            print("Doubly linked list is empty!")
            return
        
        node = self.head
        while node.next != None:
            if node.data == prev_node:
                break
            node = node.next
            
        if node.next != None:#means node.data == prev_node and loop terminated by first break
            new_node = Node(data)
            
            new_node.next = node.next
            new_node.prev = node
            node.next.prev = new_node
            node.next = new_node
            
        else: # this time node.next == None # we can check whether last node is the prev_node
            if node.data == prev_node:
                new_node = Node(data)
                
                node.next = new_node
                new_node.prev = node
                self.tail = new_node
                # note end node next will be None leave it as its
                
                
            else:
                print(f"Given node {prev_node} not found in Circular Linked List!")
        
    # 4. add_before()
    # Function to add node before the particular node
    # important point when we add new node before first Node
    def add_before(self, data, prev_node):
        if self.head is None:
            print("Circular Doubly Linked List is empty!")
            return
        
        node = self.head
        while node.next != None:
            if node.next.data == prev_node:
                break
            node = node.next
            
        if node.next != None: 
            # means loop terminate by break statement and it can be any node except first node
            # because we started from self.head.next
            new_node = Node(data)
            
            new_node.next = node.next
            new_node.prev = node
            node.next.prev = new_node
            node.next = new_node
            
        else:  # we can check whether the first node data is data before which we want to add new
               # node. if there is only one node present then that also will be handle here
            if self.head.data == prev_node:
                new_node = Node(data)
                
                self.head.prev = new_node
                new_node.next = self.head
                self.head = new_node
                                
            else:
                print(f"Given node {prev_node} is not present in Circular Linked List!")
                
    # 5. Function to add node in the end
    def add_end(self, data):
        if self.head is None:
            return self.insert_empty(data)
        else:
            new_node = Node(data)
            
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node
        

# Initialize the linked list with a new node

dll1 = DoublyLinkedList()
# dll1.createDLL(4)
# dll1.insert_empty(10)

dll1.insert_empty(100)
# dll1.add_begin(20)
dll1.add_begin(50)
dll1.add_begin(90)
# dll1.add_begin(200)

# dll1.add_after(500, 20)
# dll1.add_before(400, 20)
dll1.add_end(300)
print("Linked List forward traversal : ")
dll1.print_Forword_LL()
print("Linked List reversal taversal : ")
dll1.print_reverse_LL()
print()
print([node.data for node in dll1])

try:
    print("Head : ", dll1.head.data)
    print("Tail : ", dll1.tail.data)
    
except Exception as e:
    print(e)
# Out:
# Linked List forward traversal :
# 90 ---> 50 ---> 100 ---> 300 --->
# Linked List reversal taversal :
# 300 ---> 100 ---> 50 ---> 90 --->
#
# [90, 50, 100, 300]
# Head :  90
# Tail :  300

# %% [markdown]
# #### Time and Space Complexity
# `We need to loop over the linked list to traverse and print every element. The time complexity for traversal is O(N) where ‘N’ is the size of the given linked list. The space complexity is O(1) as no additional memory is required to traverse through a doubly linked list.`
#
#
# ### Searching in a Doubly Linked List
# To find a node in a given doubly linked list, we can use the technique of traversal. The only difference, in this case, is that as soon as we find the searched node, we will terminate the loop.
#
# The worst-case scenario for search is when we have the required element at the end of the linked list, in such a case we have to iterate through the entire linked list to find the required element.
#
# #### Searching Algorithm
# * Step 1:
# If the linked list is empty, return the message and move to step 5.
# * Step 2:
# Iterate over the linked list using the reference address for each node.
# * Step 3:
# Search every node for the given value.
# * Step 4:
# If the element is found, break the loop. If not, return the message “Element not found”.
# * Step 5:
# Terminate.
# #### Searching Method

# %%
## Creating Node class

class Node:
    def __init__(self, data = None):
        self.data = data
        self.next = None
        self.prev = None
        
# Create a doubly Linked list class to initialize head and tail reference

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
    #Iteration Function
    
    def __iter__(self):
        node = self.head
        while node:
            yield node
            node = node.next
            
    # Forward traversal 
    def print_Forword_LL(self):
        if self.head is None:
            print("The Linked List does not exist!")
            
        else:
            temp_node = self.head
            while temp_node:
                print(temp_node.data, "--->", end = " ")
                temp_node = temp_node.next
                
            print()
    
    # reverse traversal
    def print_reverse_LL(self):
        if self.head is None:
            print("The Linked List does not exist!")
        else:
            temp_head = self.tail
            while temp_head is not None:
                print(temp_head.data, "--->", end = " ")
                temp_head = temp_head.prev
            print()
          
    # Function to create Doubly Linked List
    def createDLL(self, data):
        new_node = Node(data)
        new_node.next =None
        new_node.prev = None
        self.head = new_node
        self.tail = new_node
        print("The doubly linked list has be created!")
        
    ## ------------------- Insertion Operaton -------------------------------------
    
    # 1. Insert_empty()
    # Function to insert node when Linked List is empty.
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
            self.tail = new_node
            #print("The doubly linked list has be created!")
            
        else:
            print("Node is not empty!")
            
    # 2. Add_begin()
    # Function to add node in the beginning
    def add_begin(self, data):
        if self.head is None:
            return self.insert_empty(data)
        else:
            new_node = Node(data)
            
            self.head.prev = new_node
            new_node.next = self.head
            self.head = new_node
            
    # 3. add_after()
    # Function to add node after particular node
    # in add after method we need to when node is last node because in that tail reference will
    # be change as per the new node
    def add_after(self, data, prev_node):
        
        if self.head is None:
            print("Doubly linked list is empty!")
            return
        
        node = self.head
        while node.next != None:
            if node.data == prev_node:
                break
            node = node.next
            
        if node.next != None:#means node.data == prev_node and loop terminated by first break
            new_node = Node(data)
            
            new_node.next = node.next
            new_node.prev = node
            node.next.prev = new_node
            node.next = new_node
            
        else: # this time node.next == None # we can check whether last node is the prev_node
            if node.data == prev_node:
                new_node = Node(data)
                
                node.next = new_node
                new_node.prev = node
                self.tail = new_node
                # note end node next will be None leave it as its
                
                
            else:
                print(f"Given node {prev_node} not found in Circular Linked List!")
        
    # 4. add_before()
    # Function to add node before the particular node
    # important point when we add new node before first Node
    def add_before(self, data, prev_node):
        if self.head is None:
            print("Circular Doubly Linked List is empty!")
            return
        
        node = self.head
        while node.next != None:
            if node.next.data == prev_node:
                break
            node = node.next
            
        if node.next != None: 
            # means loop terminate by break statement and it can be any node except first node
            # because we started from self.head.next
            new_node = Node(data)
            
            new_node.next = node.next
            new_node.prev = node
            node.next.prev = new_node
            node.next = new_node
            
        else:  # we can check whether the first node data is data before which we want to add new
               # node. if there is only one node present then that also will be handle here
            if self.head.data == prev_node:
                new_node = Node(data)
                
                self.head.prev = new_node
                new_node.next = self.head
                self.head = new_node
                                
            else:
                print(f"Given node {prev_node} is not present in Circular Linked List!")
                
    # 5. Function to add node in the end
    def add_end(self, data):
        if self.head is None:
            return self.insert_empty(data)
        else:
            new_node = Node(data)
            
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node
            
    ## -----------Search Algorithm---------------------
    # function to search data in Linked List
    def search_LL(self, data):
        if self.head is None:
            print("The Linked List does not exist")
            
        else:
            position = 0
            found = 0
            temp_head = self.head
            while temp_head is not None:
                position = position + 1
                if temp_head.data == data:
                    print(f"The required data found at position : {position} in Linked List")
                    found = 1
                temp_head = temp_head.next
                    
            if found == 0:
                print(f"The required data {data} not found in Linked List")
        

# Initialize the linked list with a new node

dll1 = DoublyLinkedList()
# dll1.createDLL(4)
# dll1.insert_empty(10)

dll1.insert_empty(100)
# dll1.add_begin(20)
dll1.add_begin(50)
dll1.add_begin(90)
# dll1.add_begin(200)

# dll1.add_after(500, 20)
# dll1.add_before(400, 20)
dll1.add_end(300)
print("Linked List forward traversal : ")
dll1.print_Forword_LL()
print("Linked List reversal taversal : ")
dll1.print_reverse_LL()
dll1.search_LL(300)
print()
print([node.data for node in dll1])

try:
    print("Head : ", dll1.head.data)
    print("Tail : ", dll1.tail.data)
    
except Exception as e:
    print(e)
# Out:
# Linked List forward traversal :
# 90 ---> 50 ---> 100 ---> 300 --->
# Linked List reversal taversal :
# 300 ---> 100 ---> 50 ---> 90 --->
# The required data found at position : 4 in Linked List
#
# [90, 50, 100, 300]
# Head :  90
# Tail :  300

# %% [markdown]
# #### Time and Space Complexity
#
# `The time complexity for searching a given element in the linked list is O(N) as we have to loop over all the nodes and check for the required one. The space complexity is O(1) as no additional memory is required to traverse through a doubly linked list and perform a search.`
#
#
# ### Deletion of node from Doubly Linked List
#
# To delete an existing node from a doubly linked list, we must know the value that the node holds. For deletion, we first locate the node previous to the given node. Then we point the “next” reference of this node to the next node and the “prev” reference to the previous node.
#
# `A node can be deleted from a doubly linked list in any one of the following three ways.`
#
#
# * Deleting the first node
# * Deleting any given node
# * Deleting the last node
#
# ### Deletion Algorithm
#
# #### Algorithm to delete a node from the beginning
# * Step 1: If the linked list is empty, return a null statement and go to step 6.
# * Step 2: If there’s only one element, delete that node and set head and tail to none. Go to step 6.
# * Step 3: Set a “next_node” pointing to the element next to the head node.
# * Step 4: Set the “prev” reference of “nex_node” to none.
# * Step 5: Assign “next_node” as the new head.
# * Step 6: Terminate.
#
# #### Method to delete a node from the beginning:

# %%
## Creating Node class

class Node:
    def __init__(self, data = None):
        self.data = data
        self.next = None
        self.prev = None
        
# Create a doubly Linked list class to initialize head and tail reference

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
    #Iteration Function
    
    def __iter__(self):
        node = self.head
        while node:
            yield node
            node = node.next
            
    # Forward traversal 
    def print_Forword_LL(self):
        if self.head is None:
            print("The Linked List does not exist!")
            
        else:
            temp_node = self.head
            while temp_node:
                print(temp_node.data, "--->", end = " ")
                temp_node = temp_node.next
                
            print()
    
    # reverse traversal
    def print_reverse_LL(self):
        if self.head is None:
            print("The Linked List does not exist!")
        else:
            temp_head = self.tail
            while temp_head is not None:
                print(temp_head.data, "--->", end = " ")
                temp_head = temp_head.prev
            print()
          
    # Function to create Doubly Linked List
    def createDLL(self, data):
        new_node = Node(data)
        new_node.next =None
        new_node.prev = None
        self.head = new_node
        self.tail = new_node
        print("The doubly linked list has be created!")
        
    ## ------------------- Insertion Operaton -------------------------------------
    
    # 1. Insert_empty()
    # Function to insert node when Linked List is empty.
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
            self.tail = new_node
            #print("The doubly linked list has be created!")
            
        else:
            print("Node is not empty!")
            
    # 2. Add_begin()
    # Function to add node in the beginning
    def add_begin(self, data):
        if self.head is None:
            return self.insert_empty(data)
        else:
            new_node = Node(data)
            
            self.head.prev = new_node
            new_node.next = self.head
            self.head = new_node
            
    # 3. add_after()
    # Function to add node after particular node
    # in add after method we need to when node is last node because in that tail reference will
    # be change as per the new node
    def add_after(self, data, prev_node):
        
        if self.head is None:
            print("Doubly linked list is empty!")
            return
        
        node = self.head
        while node.next != None:
            if node.data == prev_node:
                break
            node = node.next
            
        if node.next != None:#means node.data == prev_node and loop terminated by first break
            new_node = Node(data)
            
            new_node.next = node.next
            new_node.prev = node
            node.next.prev = new_node
            node.next = new_node
            
        else: # this time node.next == None # we can check whether last node is the prev_node
            if node.data == prev_node:
                new_node = Node(data)
                
                node.next = new_node
                new_node.prev = node
                self.tail = new_node
                # note end node next will be None leave it as its
                
                
            else:
                print(f"Given node {prev_node} not found in Circular Linked List!")
        
    # 4. add_before()
    # Function to add node before the particular node
    # important point when we add new node before first Node
    def add_before(self, data, prev_node):
        if self.head is None:
            print("Circular Doubly Linked List is empty!")
            return
        
        node = self.head
        while node.next != None:
            if node.next.data == prev_node:
                break
            node = node.next
            
        if node.next != None: 
            # means loop terminate by break statement and it can be any node except first node
            # because we started from self.head.next
            new_node = Node(data)
            
            new_node.next = node.next
            new_node.prev = node
            node.next.prev = new_node
            node.next = new_node
            
        else:  # we can check whether the first node data is data before which we want to add new
               # node. if there is only one node present then that also will be handle here
            if self.head.data == prev_node:
                new_node = Node(data)
                
                self.head.prev = new_node
                new_node.next = self.head
                self.head = new_node
                                
            else:
                print(f"Given node {prev_node} is not present in Circular Linked List!")
                
    # 5. Function to add node in the end
    def add_end(self, data):
        if self.head is None:
            return self.insert_empty(data)
        else:
            new_node = Node(data)
            
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node
            
    ## -----------Search Algorithm---------------------
    # function to search data in Linked List
    def search_LL(self, data):
        if self.head is None:
            print("The Linked List does not exist")
            
        else:
            position = 0
            found = 0
            temp_head = self.head
            while temp_head is not None:
                position = position + 1
                if temp_head.data == data:
                    print(f"The required data found at position : {position} in Linked List")
                    found = 1
                temp_head = temp_head.next
                    
            if found == 0:
                print(f"The required data {data} not found in Linked List")
    ## ---------------Deletion Algorithms --------------------------------
    # Delete function to delete data from beginning
    # important point when we delete node from beginning or when there is only one node exist
    def delete_begin(self):
        if self.head is None:
            print("The Linked lit does not exist!")
            return
        if self.head.next == self.tail.next :
            self.head = self.tail = None
            return
        elif self.head is not None:
            next_node = self.head.next
            next_node.prev = None
            self.head = next_node
            return

# Initialize the linked list with a new node

dll1 = DoublyLinkedList()
# dll1.createDLL(4)
# dll1.insert_empty(10)

dll1.insert_empty(100)
# dll1.add_begin(20)
# dll1.add_begin(50)
# dll1.add_begin(90)
# dll1.add_begin(200)

# dll1.add_after(500, 20)
# dll1.add_before(400, 20)
dll1.add_end(300)
print("Linked List forward traversal : ")
dll1.print_Forword_LL()
# print("Linked List reversal taversal : ")
# dll1.print_reverse_LL()
# dll1.search_LL(300)
# print()
print([node.data for node in dll1])
dll1.delete_begin()
print("Linked List forward traversal : ")
dll1.print_Forword_LL()
try:
    print("Head : ", dll1.head.data)
    print("Tail : ", dll1.tail.data)
    
except Exception as e:
    print(e)
# Out:
# Linked List forward traversal :
# 100 ---> 300 --->
# [100, 300]
# Linked List forward traversal :
# 300 --->
# Head :  300
# Tail :  300

# %% [markdown]
# ### Algorithm to delete a node from between the linked list (delete by value)
#
# * Step 1: If the linked list is empty, return a null statement and go to step 7.
#
# * Step 2: Create a “temp_node” and set it to the head node. Iterate over the list till the element to be deleted is found.
# * Step 3: Set “prev_node” as the element behind the node to be deleted.
# * Step 4: Set “next_node” as the element after the node to be deleted.
# * Step 5: Assign the “next” reference of “prev_node” to the “next_node”.
# * Step 6: Assign the “prev” reference of “next_node” to the “prev_node”.
# * Step 7: Terminate.
#
# ####  Method to delete a node from between the linked list

# %%
## Creating Node class

class Node:
    def __init__(self, data = None):
        self.data = data
        self.next = None
        self.prev = None
        
# Create a doubly Linked list class to initialize head and tail reference

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
    #Iteration Function
    
    def __iter__(self):
        node = self.head
        while node:
            yield node
            node = node.next
            
    # Forward traversal 
    def print_Forword_LL(self):
        if self.head is None:
            print("The Linked List does not exist!")
            
        else:
            temp_node = self.head
            while temp_node:
                print(temp_node.data, "--->", end = " ")
                temp_node = temp_node.next
                
            print()
    
    # reverse traversal
    def print_reverse_LL(self):
        if self.head is None:
            print("The Linked List does not exist!")
        else:
            node= self.tail
            while node is not None:
                print(temp_head.data, "--->", end = " ")
                node= temp_head.prev
            print()
          
    # Function to create Doubly Linked List
    def createDLL(self, data):
        new_node = Node(data)
        new_node.next =None
        new_node.prev = None
        self.head = new_node
        self.tail = new_node
        print("The doubly linked list has be created!")
        
    ## ------------------- Insertion Operaton -------------------------------------
    
    # 1. Insert_empty()
    # Function to insert node when Linked List is empty.
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
            self.tail = new_node
            #print("The doubly linked list has be created!")
            
        else:
            print("Node is not empty!")
            
    # 2. Add_begin()
    # Function to add node in the beginning
    def add_begin(self, data):
        if self.head is None:
            return self.insert_empty(data)
        else:
            new_node = Node(data)
            
            self.head.prev = new_node
            new_node.next = self.head
            self.head = new_node
            
    # 3. add_after()
    # Function to add node after particular node
    # in add after method we need to when node is last node because in that tail reference will
    # be change as per the new node
    def add_after(self, data, prev_node):
        
        if self.head is None:
            print("Doubly linked list is empty!")
            return
        
        node = self.head
        while node.next != None:
            if node.data == prev_node:
                break
            node = node.next
            
        if node.next != None:#means node.data == prev_node and loop terminated by first break
            new_node = Node(data)
            
            new_node.next = node.next
            new_node.prev = node
            node.next.prev = new_node
            node.next = new_node
            
        else: # this time node.next == None # we can check whether last node is the prev_node
            if node.data == prev_node:
                new_node = Node(data)
                
                node.next = new_node
                new_node.prev = node
                self.tail = new_node
                # note end node next will be None leave it as its
                
                
            else:
                print(f"Given node {prev_node} not found in Circular Linked List!")
        
    # 4. add_before()
    # Function to add node before the particular node
    # important point when we add new node before first Node
    def add_before(self, data, prev_node):
        if self.head is None:
            print("Circular Doubly Linked List is empty!")
            return
        
        node = self.head
        while node.next != None:
            if node.next.data == prev_node:
                break
            node = node.next
            
        if node.next != None: 
            # means loop terminate by break statement and it can be any node except first node
            # because we started from self.head.next
            new_node = Node(data)
            
            new_node.next = node.next
            new_node.prev = node
            node.next.prev = new_node
            node.next = new_node
            
        else:  # we can check whether the first node data is data before which we want to add new
               # node. if there is only one node present then that also will be handle here
            if self.head.data == prev_node:
                new_node = Node(data)
                
                self.head.prev = new_node
                new_node.next = self.head
                self.head = new_node
                                
            else:
                print(f"Given node {prev_node} is not present in Circular Linked List!")
                
    # 5. Function to add node in the end
    def add_end(self, data):
        if self.head is None:
            return self.insert_empty(data)
        else:
            new_node = Node(data)
            
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node
            
    ## -----------Search Algorithm---------------------
    # function to search data in Linked List
    def search_LL(self, data):
        if self.head is None:
            print("The Linked List does not exist")
            
        else:
            position = 0
            found = 0
            node= self.head
            while node is not None:
                position = position + 1
                if temp_head.data == data:
                    print(f"The required data found at position : {position} in Linked List")
                    found = 1
                node= temp_head.next
                    
            if found == 0:
                print(f"The required data {data} not found in Linked List")
    ## ---------------Deletion Algorithms --------------------------------
    # 1. Delete function to delete node from beginning
    # important point when we delete node from beginning or when there is only one node exist
    def delete_begin(self):
        if self.head is None:
            print("The Linked lit does not exist!")
            return
        if self.head.next == self.tail.next :
            self.head = self.tail = None
            return
        elif self.head is not None:
            next_node = self.head.next
            next_node.prev = None
            self.head = next_node
            return
        
    # 2. Function to delete node by node data
    # important point when we will delete from begin and end
    def delete_by_value(self, value):
        if self.head is None:
            print("Cann't delete Linked List is empty!")
            return
        
        # when there is only one node  and want to delete that
        elif self.head == self.tail:
            if self.head.data == value:
                self.head = self.tail = None
                return
            else:
                print(f"Given node {value} is not present in Linked List")
        
        node = self.head
        # checking whether first node is node which we want to delete
        if node is not None: 
            # if node is the first node.
            if node.data == value:
                temp_node = self.head
                self.head = self.head.next
                temp_node = None
                return
              
        while node.next != self.tail:
            if node.next.data == value:
                break
            node = node.next
            
        if node.next!= self.tail: # means node.next.data = prev_node because loop terminated by
                                  # break statement
                temp_node = node.next
                node.next = node.next.next
                node.next.prev = node
                temp_node = None
                
        else:# now node.next == self.tail i.e. we are at last node 
            # we can check whether the last node is the node which we want to delete
            if node.next.data == value: # means tail value
                temp_node = node.next
                self.tail = node
                self.tail.next = None
                temp_node = None
                return
            
            else:
                print(f"Given node {value} is not present in CSLL!")
# Initialize the linked list with a new node

dll1 = DoublyLinkedList()
# dll1.createDLL(4)
# dll1.insert_empty(10)

dll1.insert_empty(100)
# dll1.add_begin(20)
# dll1.add_begin(50)
# dll1.add_begin(90)
dll1.add_begin(200)

# dll1.add_after(500, 20)
# dll1.add_before(400, 20)
dll1.add_end(300)
print("Linked List forward traversal : ")
dll1.print_Forword_LL()
# print("Linked List reversal taversal : ")
# dll1.print_reverse_LL()
# dll1.search_LL(300)
# print()
print([node.data for node in dll1])
# dll1.delete_begin()
dll1.delete_by_value(300)
print("Linked List forward traversal after deletion : ")
dll1.print_Forword_LL()
print()
try:
    print("Head : ", dll1.head.data)
    print("Tail : ", dll1.tail.data)
    
except Exception as e:
    print(e)
# Out:
# Linked List forward traversal :
# 200 ---> 100 ---> 300 --->
# [200, 100, 300]
# Linked List forward traversal after deletion :
# 200 ---> 100 --->
#
# Head :  200
# Tail :  100

# %% [markdown]
# #### Algorithm to delete a node from the end
#
# * Step 1: If the linked list is empty, return a null statement and go to step 7.
#
# * Step 2: If there’s only one element, delete that node and set head and tail to none. Go to step 7.
# * Step 3: Set a “temp_node” pointing at head. Iterate the linked list till that node points to the second last node of the list.
# * Step 4: Assign tail as the temp node. Set temp node to the next node, i.e., last in the list.
# * Step 5: Delete the temp_node.
# * Step 6: Assign “head” to the “next” reference of the tail.
# * Step 7: Terminate.
#
# #### Method to delete a node from the end

# %%
## Creating Node class

class Node:
    def __init__(self, data = None):
        self.data = data
        self.next = None
        self.prev = None
        
# Create a doubly Linked list class to initialize head and tail reference

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
    #Iteration Function
    
    def __iter__(self):
        node = self.head
        while node:
            yield node
            node = node.next
            
    # Forward traversal 
    def print_Forword_LL(self):
        if self.head is None:
            print("The Linked List does not exist!")
            
        else:
            temp_node = self.head
            while temp_node:
                print(temp_node.data, "--->", end = " ")
                temp_node = temp_node.next
                
            print()
    
    # reverse traversal
    def print_reverse_LL(self):
        if self.head is None:
            print("The Linked List does not exist!")
        else:
            node= self.tail
            while node is not None:
                print(temp_head.data, "--->", end = " ")
                node= temp_head.prev
            print()
          
    # Function to create Doubly Linked List
    def createDLL(self, data):
        new_node = Node(data)
        new_node.next =None
        new_node.prev = None
        self.head = new_node
        self.tail = new_node
        print("The doubly linked list has be created!")
        
    ## ------------------- Insertion Operaton -------------------------------------
    
    # 1. Insert_empty()
    # Function to insert node when Linked List is empty.
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
            self.tail = new_node
            #print("The doubly linked list has be created!")
            
        else:
            print("Node is not empty!")
            
    # 2. Add_begin()
    # Function to add node in the beginning
    def add_begin(self, data):
        if self.head is None:
            return self.insert_empty(data)
        else:
            new_node = Node(data)
            
            self.head.prev = new_node
            new_node.next = self.head
            self.head = new_node
            
    # 3. add_after()
    # Function to add node after particular node
    # in add after method we need to when node is last node because in that tail reference will
    # be change as per the new node
    def add_after(self, data, prev_node):
        
        if self.head is None:
            print("Doubly linked list is empty!")
            return
        
        node = self.head
        while node.next != None:
            if node.data == prev_node:
                break
            node = node.next
            
        if node.next != None:#means node.data == prev_node and loop terminated by first break
            new_node = Node(data)
            
            new_node.next = node.next
            new_node.prev = node
            node.next.prev = new_node
            node.next = new_node
            
        else: # this time node.next == None # we can check whether last node is the prev_node
            if node.data == prev_node:
                new_node = Node(data)
                
                node.next = new_node
                new_node.prev = node
                self.tail = new_node
                # note end node next will be None leave it as its
                
                
            else:
                print(f"Given node {prev_node} not found in Circular Linked List!")
        
    # 4. add_before()
    # Function to add node before the particular node
    # important point when we add new node before first Node
    def add_before(self, data, prev_node):
        if self.head is None:
            print("Circular Doubly Linked List is empty!")
            return
        
        node = self.head
        while node.next != None:
            if node.next.data == prev_node:
                break
            node = node.next
            
        if node.next != None: 
            # means loop terminate by break statement and it can be any node except first node
            # because we started from self.head.next
            new_node = Node(data)
            
            new_node.next = node.next
            new_node.prev = node
            node.next.prev = new_node
            node.next = new_node
            
        else:  # we can check whether the first node data is data before which we want to add new
               # node. if there is only one node present then that also will be handle here
            if self.head.data == prev_node:
                new_node = Node(data)
                
                self.head.prev = new_node
                new_node.next = self.head
                self.head = new_node
                                
            else:
                print(f"Given node {prev_node} is not present in Circular Linked List!")
                
    # 5. Function to add node in the end
    def add_end(self, data):
        if self.head is None:
            return self.insert_empty(data)
        else:
            new_node = Node(data)
            
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node
            
    ## -----------Search Algorithm---------------------
    # function to search data in Linked List
    def search_LL(self, data):
        if self.head is None:
            print("The Linked List does not exist")
            
        else:
            position = 0
            found = 0
            node= self.head
            while node is not None:
                position = position + 1
                if temp_head.data == data:
                    print(f"The required data found at position : {position} in Linked List")
                    found = 1
                node= temp_head.next
                    
            if found == 0:
                print(f"The required data {data} not found in Linked List")
    ## ---------------Deletion Algorithms --------------------------------
    # 1. Delete function to delete node from beginning
    # important point when we delete node from beginning or when there is only one node exist
    def delete_begin(self):
        if self.head is None:
            print("The Linked lit does not exist!")
            return
        if self.head.next == self.tail.next :
            self.head = self.tail = None
            return
        elif self.head is not None:
            next_node = self.head.next
            next_node.prev = None
            self.head = next_node
            return
        
    # 2. Function to delete node by node data
    # important point when we will delete from begin and end
    def delete_by_value(self, value):
        if self.head is None:
            print("Cann't delete Linked List is empty!")
            return
        
        # when there is only one node  and want to delete that
        elif self.head == self.tail:
            if self.head.data == value:
                self.head = self.tail = None
                return
            else:
                print(f"Given node {value} is not present in Linked List")
        
        node = self.head
        # checking whether first node is node which we want to delete
        if node is not None: 
            # if node is the first node.
            if node.data == value:
                temp_node = self.head
                self.head = self.head.next
                temp_node = None
                return
              
        while node.next != self.tail:
            if node.next.data == value:
                break
            node = node.next
            
        if node.next!= self.tail: # means node.next.data = prev_node because loop terminated by
                                  # break statement
                temp_node = node.next
                node.next = node.next.next
                node.next.prev = node
                temp_node = None
                
        else:# now node.next == self.tail i.e. we are at last node 
            # we can check whether the last node is the node which we want to delete
            if node.next.data == value: # means tail value
                temp_node = node.next
                self.tail = node
                self.tail.next = None
                temp_node = None
                return
            
            else:
                print(f"Given node {value} is not present in CSLL!")
                
    # 3. delete end 
    # Function to delete node from the end
    def delete_end(self):
        if self.head is None:
            print("The Linked list does not exist!")
            return
        
        elif self.head.next == self.tail.next:
            self.head = self.tail = None
            return 
        else:
            temp_node = self.head
            while temp_node.next is not self.tail:
                temp_node = temp_node.next
                
            self.tail = temp_node
            temp_node.next = None
            return

# Initialize the linked list with a new node
dll1 = DoublyLinkedList()
# dll1.createDLL(4)
# dll1.insert_empty(10)

dll1.insert_empty(100)
dll1.add_begin(20)
dll1.add_begin(50)
dll1.add_begin(90)
dll1.add_begin(200)

# dll1.add_after(500, 20)
# dll1.add_before(400, 20)
dll1.add_end(300)
print("Linked List forward traversal : ")
dll1.print_Forword_LL()
# print("Linked List reversal taversal : ")
# dll1.print_reverse_LL()
# dll1.search_LL(300)
# print()
print([node.data for node in dll1])
# dll1.delete_begin()
# dll1.delete_by_value(300)
dll1.delete_end()
print("Linked List forward traversal after deletion : ")
dll1.print_Forword_LL()
print()
try:
    print("Head : ", dll1.head.data)
    print("Tail : ", dll1.tail.data)
    
except Exception as e:
    print(e)
# Out:
# Linked List forward traversal :
# 200 ---> 90 ---> 50 ---> 20 ---> 100 ---> 300 --->
# [200, 90, 50, 20, 100, 300]
# Linked List forward traversal after deletion :
# 200 ---> 90 ---> 50 ---> 20 ---> 100 --->
#
# Head :  200
# Tail :  100

# %% [markdown]
# #### Time and Space Complexity
#
# `The time complexity for deletion in a doubly linked list is O(N) as we have to loop over all the nodes and search for the required one. The space complexity is O(1) as no additional memory is required to delete an element from a doubly linked list.`
#
# #### Deletion of entire Doubly Linked List
# The deletion of an entire doubly linked list is quite a simple process. We need to set the previous references of all nodes in the list to none. Then, we have to set the two reference nodes “head” and “tail” to none.
#
#
# #### Algorithm to delete an entire doubly linked list
#
# * Step 1: If the linked list is empty, return an error message and go to step 5.
# * Step 2: Iterate over the linked list and set all the previous references to none.
# * Step 3: Delete the “head” node by setting it to none.
# * Step 4: Delete the “tail” node by setting it to none.
# * Step 5: Terminate.
# #### Method to delete an entire doubly linked listm

# %%
## Creating Node class

class Node:
    def __init__(self, data = None):
        self.data = data
        self.next = None
        self.prev = None
        
# Create a doubly Linked list class to initialize head and tail reference

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
    #Iteration Function
    
    def __iter__(self):
        node = self.head
        while node:
            yield node
            node = node.next
            
    # Forward traversal 
    def print_Forword_LL(self):
        if self.head is None:
            print("The Linked List does not exist!")
            
        else:
            temp_node = self.head
            while temp_node:
                print(temp_node.data, "--->", end = " ")
                temp_node = temp_node.next
                
            print()
    
    # reverse traversal
    def print_reverse_LL(self):
        if self.head is None:
            print("The Linked List does not exist!")
        else:
            node= self.tail
            while node is not None:
                print(temp_head.data, "--->", end = " ")
                node= temp_head.prev
            print()
          
    # Function to create Doubly Linked List
    def createDLL(self, data):
        new_node = Node(data)
        new_node.next =None
        new_node.prev = None
        self.head = new_node
        self.tail = new_node
        print("The doubly linked list has be created!")
        
    ## ------------------- Insertion Operaton -------------------------------------
    
    # 1. Insert_empty()
    # Function to insert node when Linked List is empty.
    def insert_empty(self, data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
            self.tail = new_node
            #print("The doubly linked list has be created!")
            
        else:
            print("Node is not empty!")
            
    # 2. Add_begin()
    # Function to add node in the beginning
    def add_begin(self, data):
        if self.head is None:
            return self.insert_empty(data)
        else:
            new_node = Node(data)
            
            self.head.prev = new_node
            new_node.next = self.head
            self.head = new_node
            
    # 3. add_after()
    # Function to add node after particular node
    # in add after method we need to when node is last node because in that tail reference will
    # be change as per the new node
    def add_after(self, data, prev_node):
        
        if self.head is None:
            print("Doubly linked list is empty!")
            return
        
        node = self.head
        while node.next != None:
            if node.data == prev_node:
                break
            node = node.next
            
        if node.next != None:#means node.data == prev_node and loop terminated by first break
            new_node = Node(data)
            
            new_node.next = node.next
            new_node.prev = node
            node.next.prev = new_node
            node.next = new_node
            
        else: # this time node.next == None # we can check whether last node is the prev_node
            if node.data == prev_node:
                new_node = Node(data)
                
                node.next = new_node
                new_node.prev = node
                self.tail = new_node
                # note end node next will be None leave it as its
                
                
            else:
                print(f"Given node {prev_node} not found in Circular Linked List!")
        
    # 4. add_before()
    # Function to add node before the particular node
    # important point when we add new node before first Node
    def add_before(self, data, prev_node):
        if self.head is None:
            print("Circular Doubly Linked List is empty!")
            return
        
        node = self.head
        while node.next != None:
            if node.next.data == prev_node:
                break
            node = node.next
            
        if node.next != None: 
            # means loop terminate by break statement and it can be any node except first node
            # because we started from self.head.next
            new_node = Node(data)
            
            new_node.next = node.next
            new_node.prev = node
            node.next.prev = new_node
            node.next = new_node
            
        else:  # we can check whether the first node data is data before which we want to add new
               # node. if there is only one node present then that also will be handle here
            if self.head.data == prev_node:
                new_node = Node(data)
                
                self.head.prev = new_node
                new_node.next = self.head
                self.head = new_node
                                
            else:
                print(f"Given node {prev_node} is not present in Circular Linked List!")
                
    # 5. Function to add node in the end
    def add_end(self, data):
        if self.head is None:
            return self.insert_empty(data)
        else:
            new_node = Node(data)
            
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node
            
    ## -----------Search Algorithm---------------------
    # function to search data in Linked List
    def search_LL(self, data):
        if self.head is None:
            print("The Linked List does not exist")
            
        else:
            position = 0
            found = 0
            node= self.head
            while node is not None:
                position = position + 1
                if temp_head.data == data:
                    print(f"The required data found at position : {position} in Linked List")
                    found = 1
                node= temp_head.next
                    
            if found == 0:
                print(f"The required data {data} not found in Linked List")
    ## ---------------Deletion Algorithms --------------------------------
    # 1. Delete function to delete node from beginning
    # important point when we delete node from beginning or when there is only one node exist
    def delete_begin(self):
        if self.head is None:
            print("The Linked lit does not exist!")
            return
        if self.head.next == self.tail.next :
            self.head = self.tail = None
            return
        elif self.head is not None:
            next_node = self.head.next
            next_node.prev = None
            self.head = next_node
            return
        
    # 2. Function to delete node by node data
    # important point when we will delete from begin and end
    def delete_by_value(self, value):
        if self.head is None:
            print("Cann't delete Linked List is empty!")
            return
        
        # when there is only one node  and want to delete that
        elif self.head == self.tail:
            if self.head.data == value:
                self.head = self.tail = None
                return
            else:
                print(f"Given node {value} is not present in Linked List")
        
        node = self.head
        # checking whether first node is node which we want to delete
        if node is not None: 
            # if node is the first node.
            if node.data == value:
                temp_node = self.head
                self.head = self.head.next
                temp_node = None
                return
              
        while node.next != self.tail:
            if node.next.data == value:
                break
            node = node.next
            
        if node.next!= self.tail: # means node.next.data = prev_node because loop terminated by
                                  # break statement
                temp_node = node.next
                node.next = node.next.next
                node.next.prev = node
                temp_node = None
                
        else:# now node.next == self.tail i.e. we are at last node 
            # we can check whether the last node is the node which we want to delete
            if node.next.data == value: # means tail value
                temp_node = node.next
                self.tail = node
                self.tail.next = None
                temp_node = None
                return
            
            else:
                print(f"Given node {value} is not present in CSLL!")
                
    # 3. delete end 
    # Function to delete node from the end
    def delete_end(self):
        if self.head is None:
            print("The Linked list does not exist!")
            return
        
        elif self.head.next == self.tail.next:
            self.head = self.tail = None
            return 
        else:
            temp_node = self.head
            while temp_node.next is not self.tail:
                temp_node = temp_node.next
                
            self.tail = temp_node
            temp_node.next = None
            return
    # 4. delete entire Doubly Linked List
    # Function to delete an entire doubly Linked List
    
    def delete_Doubly_LL(self):
        if self.head is None:
            print("The doubly linked list does not exist!")
            
        else:
            temp_node = self.head
            while temp_node:
                temp_node.prev = None
                temp_node = temp_node.next
                
            self.head = None
            self.tail = None
            
        print("The Doubly Linked List has been deleted!")

# Initialize the linked list with a new node
dll1 = DoublyLinkedList()
# dll1.createDLL(4)
# dll1.insert_empty(10)

dll1.insert_empty(100)
dll1.add_begin(20)
dll1.add_begin(50)
dll1.add_begin(90)
dll1.add_begin(200)

# dll1.add_after(500, 20)
# dll1.add_before(400, 20)
dll1.add_end(300)
print("Linked List forward traversal : ")
dll1.print_Forword_LL()
# print("Linked List reversal taversal : ")
# dll1.print_reverse_LL()
# dll1.search_LL(300)
# print()
print([node.data for node in dll1])
# dll1.delete_begin()
# dll1.delete_by_value(300)
# dll1.delete_end()
dll1.delete_Doubly_LL()
print("Linked List forward traversal after deletion : ")
dll1.print_Forword_LL()
print()
try:
    print("Head : ", dll1.head.data)
    print("Tail : ", dll1.tail.data)
    
except Exception as e:
    print(e)
# Out:
# Linked List forward traversal :
# 200 ---> 90 ---> 50 ---> 20 ---> 100 ---> 300 --->
# [200, 90, 50, 20, 100, 300]
# The Doubly Linked List has been deleted!
# Linked List forward traversal after deletion :
# The Linked List does not exist!
#
# 'NoneType' object has no attribute 'data'

# %% [markdown]
# #### Time and Space Complexity
# The time complexity for deletion of an entire doubly linked list is O(N) because we need to iterate over the entire list to set all previous references to none. The space complexity is O(1) since there is no additional space required when deleting the references.
